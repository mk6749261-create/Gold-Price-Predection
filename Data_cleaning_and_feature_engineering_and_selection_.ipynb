# %%
import pandas as pd

df = pd.read_csv('/content/gold_dataset.csv')
df_before = df.copy()

# %%
df.head()
# Out:
#          Date  Gold_Price  Silver    Oil_WTI    Platinum  Copper        SP500  \
# 0  2000-08-30  273.899994   4.930  33.400002  591.400024  0.8850  1502.589966
# 1  2000-08-31  278.299988   5.003  33.099998  586.700012  0.8850  1517.680054
# 2  2000-09-01  277.000000   5.004  33.380001  595.299988  0.8890  1520.770020
# 3  2000-09-05  275.799988   4.998  33.799999  601.299988  0.9060  1507.079956
# 4  2000-09-06  274.200012   4.983  34.950001  611.099976  0.9015  1492.250000
#
#         Nasdaq     Dow_Jones  MSCI_World  ...  Momentum_14d  \
# 0  4103.810059  11103.009766         NaN  ...           NaN
# 1  4206.350098  11215.099609         NaN  ...           NaN
# 2  4234.330078  11238.780273         NaN  ...           NaN
# 3  4143.180176  11260.610352         NaN  ...           NaN
# 4  4013.340088  11310.639648         NaN  ...           NaN
#
#    Gold_Silver_Ratio  Gold_Oil_Ratio  DayOfWeek  Month  Quarter    Year  \
# 0          55.557810        8.200598        2.0    8.0      3.0  2000.0
# 1          55.626624        8.407855        3.0    8.0      3.0  2000.0
# 2          55.355713        8.298382        4.0    9.0      3.0  2000.0
# 3          55.182069        8.159763        1.0    9.0      3.0  2000.0
# 4          55.027097        7.845494        2.0    9.0      3.0  2000.0
#
#    Target_NextDay  Target_Next7d  Target_Direction
# 0      278.299988     273.299988               1.0
# 1      277.000000     273.100006               0.0
# 2             NaN     272.899994               0.0
# 3      274.200012     272.399994               0.0
# 4      274.000000     272.299988               0.0
#
# [5 rows x 70 columns]

# %%
df.shape
# Out:
# (2328, 70)

# %%
df.columns
# Out:
# Index(['Date', 'Gold_Price', 'Silver', 'Oil_WTI', 'Platinum', 'Copper',
#        'SP500', 'Nasdaq', 'Dow_Jones', 'MSCI_World', 'DXY', 'EUR_USD',
#        'JPY_USD', 'GBP_USD', 'CNY_USD', 'US_10Y_Yield', 'US_2Y_Yield',
#        'TIP_ETF', 'VIX', 'Gold_ETF_GLD', 'CPI', 'Fed_Rate', 'Real_Rate_10Y',
#        'PPI', 'M2_Money', 'Treasury_Spread', 'Unemployment', 'GDP_Growth',
#        'Industrial_Prod', 'Consumer_Conf', 'MA7', 'EMA7', 'MA14', 'EMA14',
#        'MA21', 'EMA21', 'MA50', 'EMA50', 'MA200', 'EMA200', 'Return_1d',
#        'Return_3d', 'Return_7d', 'Return_14d', 'Return_30d', 'Lag_1d',
#        'Lag_3d', 'Lag_7d', 'Lag_14d', 'Lag_21d', 'RSI_14', 'MACD',
#        'MACD_Signal', 'MACD_Hist', 'BB_Upper', 'BB_Lower', 'BB_Width',
#        'BB_Pos', 'Volatility_7d', 'Volatility_30d', 'Momentum_14d',
#        'Gold_Silver_Ratio', 'Gold_Oil_Ratio', 'DayOfWeek', 'Month', 'Quarter',
#        'Year', 'Target_NextDay', 'Target_Next7d', 'Target_Direction'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2328 entries, 0 to 2327
# Data columns (total 70 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               2328 non-null   object
#  1   Gold_Price         2328 non-null   float64
#  2   Silver             2327 non-null   float64
#  3   Oil_WTI            2327 non-null   float64
#  4   Platinum           1642 non-null   float64
#  5   Copper             2327 non-null   float64
#  6   SP500              2324 non-null   float64
#  7   Nasdaq             2324 non-null   float64
#  8   Dow_Jones          2324 non-null   float64
#  9   MSCI_World         0 non-null      float64
#  10  DXY                2325 non-null   float64
#  11  EUR_USD            1493 non-null   float64
#  12  JPY_USD            2303 non-null   float64
#  13  GBP_USD            1506 non-null   float64
#  14  CNY_USD            1890 non-null   float64
#  15  US_10Y_Yield       2320 non-null   float64
#  16  US_2Y_Yield        2320 non-null   float64
#  17  TIP_ETF            1511 non-null   float64
#  18  VIX                2324 non-null   float64
#  19  Gold_ETF_GLD       1273 non-null   float64
#  20  CPI                2327 non-null   float64
#  21  Fed_Rate           2327 non-null   float64
#  22  Real_Rate_10Y      2327 non-null   float64
#  23  PPI                2327 non-null   float64
#  24  M2_Money           2327 non-null   float64
#  25  Treasury_Spread    2327 non-null   float64
#  26  Unemployment       2327 non-null   float64
#  27  GDP_Growth         2243 non-null   float64
#  28  Industrial_Prod    2327 non-null   float64
#  29  Consumer_Conf      2327 non-null   float64
#  30  MA7                1829 non-null   float64
#  31  EMA7               2327 non-null   float64
#  32  MA14               1330 non-null   float64
#  33  EMA14              2327 non-null   float64
#  34  MA21               897 non-null    float64
#  35  EMA21              2327 non-null   float64
#  36  MA50               131 non-null    float64
#  37  EMA50              2327 non-null   float64
#  38  MA200              0 non-null      float64
#  39  EMA200             2327 non-null   float64
#  40  Return_1d          2326 non-null   float64
#  41  Return_3d          2324 non-null   float64
#  42  Return_7d          2321 non-null   float64
#  43  Return_14d         2314 non-null   float64
#  44  Return_30d         2298 non-null   float64
#  45  Lag_1d             2238 non-null   float64
#  46  Lag_3d             2225 non-null   float64
#  47  Lag_7d             2221 non-null   float64
#  48  Lag_14d            2215 non-null   float64
#  49  Lag_21d            2213 non-null   float64
#  50  RSI_14             1265 non-null   float64
#  51  MACD               2327 non-null   float64
#  52  MACD_Signal        2327 non-null   float64
#  53  MACD_Hist          2327 non-null   float64
#  54  BB_Upper           950 non-null    float64
#  55  BB_Lower           950 non-null    float64
#  56  BB_Width           950 non-null    float64
#  57  BB_Pos             950 non-null    float64
#  58  Volatility_7d      2321 non-null   float64
#  59  Volatility_30d     2298 non-null   float64
#  60  Momentum_14d       2215 non-null   float64
#  61  Gold_Silver_Ratio  2326 non-null   float64
#  62  Gold_Oil_Ratio     2326 non-null   float64
#  63  DayOfWeek          2327 non-null   float64
#  64  Month              2327 non-null   float64
#  65  Quarter            2327 non-null   float64
#  66  Year               2327 non-null   float64
#  67  Target_NextDay     2239 non-null   float64
#  68  Target_Next7d      2227 non-null   float64
#  69  Target_Direction   2327 non-null   float64
# dtypes: float64(69), object(1)
# memory usage: 1.2+ MB

# %%
for col in df.columns:
    print(col, " = ",df[col].isnull().sum())
# Out:
# Date  =  0
# Gold_Price  =  0
# Silver  =  1
# Oil_WTI  =  1
# Platinum  =  686
# Copper  =  1
# SP500  =  4
# Nasdaq  =  4
# Dow_Jones  =  4
# MSCI_World  =  2328
# DXY  =  3
# EUR_USD  =  835
# JPY_USD  =  25
# GBP_USD  =  822
# CNY_USD  =  438
# US_10Y_Yield  =  8
# US_2Y_Yield  =  8
# TIP_ETF  =  817
# VIX  =  4
# Gold_ETF_GLD  =  1055
# CPI  =  1
# Fed_Rate  =  1
# Real_Rate_10Y  =  1
# PPI  =  1
# M2_Money  =  1
# Treasury_Spread  =  1
# Unemployment  =  1
# GDP_Growth  =  85
# Industrial_Prod  =  1
# Consumer_Conf  =  1
# MA7  =  499
# EMA7  =  1
# MA14  =  998
# EMA14  =  1
# MA21  =  1431
# EMA21  =  1
# MA50  =  2197
# EMA50  =  1
# MA200  =  2328
# EMA200  =  1
# Return_1d  =  2
# Return_3d  =  4
# Return_7d  =  7
# Return_14d  =  14
# Return_30d  =  30
# Lag_1d  =  90
# Lag_3d  =  103
# Lag_7d  =  107
# Lag_14d  =  113
# Lag_21d  =  115
# RSI_14  =  1063
# MACD  =  1
# MACD_Signal  =  1
# MACD_Hist  =  1
# BB_Upper  =  1378
# BB_Lower  =  1378
# BB_Width  =  1378
# BB_Pos  =  1378
# Volatility_7d  =  7
# Volatility_30d  =  30
# Momentum_14d  =  113
# Gold_Silver_Ratio  =  2
# Gold_Oil_Ratio  =  2
# DayOfWeek  =  1
# Month  =  1
# Quarter  =  1
# Year  =  1
# Target_NextDay  =  89
# Target_Next7d  =  101
# Target_Direction  =  1

# %%
df.isnull().sum()
# Out:
# Date                  0
# Gold_Price            0
# Silver                1
# Oil_WTI               1
# Platinum            686
#                    ...
# Quarter               1
# Year                  1
# Target_NextDay       89
# Target_Next7d       101
# Target_Direction      1
# Length: 70, dtype: int64

# %%
df.describe()
# Out:
#         Gold_Price       Silver      Oil_WTI     Platinum       Copper  \
# count  2328.000000  2327.000000  2327.000000  1642.000000  2327.000000
# mean    539.290163     8.998762    52.812372   874.587759     1.858390
# std     242.093567     4.442333    26.101521   365.746549     1.097162
# min     255.100006     4.026000    17.450001   412.500000     0.604000
# 25%     328.700012     4.762500    30.185000   593.599976     0.790000
# 50%     434.250000     7.253000    48.970001   842.199982     1.482000
# 75%     696.549988    12.950000    67.355000  1064.024994     2.982500
# max    1217.400024    20.684999   145.289993  2251.100098     4.077500
#
#              SP500       Nasdaq     Dow_Jones  MSCI_World          DXY  ...  \
# count  2324.000000  2324.000000   2324.000000         0.0  2325.000000  ...
# mean   1169.147285  2061.202269  10453.983864         NaN    92.071462  ...
# std     192.602319   442.619684   1502.049970         NaN    13.712544  ...
# min     676.530029  1114.109985   6547.049805         NaN    71.330002  ...
# 25%    1035.047516  1792.272461   9508.760254         NaN    82.510002  ...
# 50%    1172.775024  2059.760010  10441.965332         NaN    87.989998  ...
# 75%    1305.107452  2311.312439  11174.152344         NaN   102.010002  ...
# max    1565.150024  4234.330078  14164.530273         NaN   120.900002  ...
#
#        Momentum_14d  Gold_Silver_Ratio  Gold_Oil_Ratio    DayOfWeek  \
# count   2215.000000        2326.000000     2326.000000  2327.000000
# mean       4.897201          61.949031       10.735182     2.016330
# std       29.839539           8.261688        3.008497     1.398221
# min     -163.799988          43.630595        6.176766     0.000000
# 25%       -6.899994          55.709638        8.737100     1.000000
# 50%        3.700012          61.412895       10.044584     2.000000
# 75%       16.549988          67.342453       11.983512     3.000000
# max      139.400024          84.328672       28.240902     4.000000
#
#              Month      Quarter         Year  Target_NextDay  Target_Next7d  \
# count  2327.000000  2327.000000  2327.000000     2239.000000    2227.000000
# mean      6.649764     2.549635  2004.820370      539.952613     542.551100
# std       3.439038     1.119286     2.696684      242.400955     243.737011
# min       1.000000     1.000000  2000.000000      255.100006     255.100006
# 25%       4.000000     2.000000  2003.000000      328.700012     333.300003
# 50%       7.000000     3.000000  2005.000000      434.500000     435.899994
# 75%      10.000000     4.000000  2007.000000      703.500000     714.549988
# max      12.000000     4.000000  2009.000000     1217.400024    1217.400024
#
#        Target_Direction
# count       2327.000000
# mean           0.503223
# std            0.500097
# min            0.000000
# 25%            0.000000
# 50%            1.000000
# 75%            1.000000
# max            1.000000
#
# [8 rows x 69 columns]

# %%
for col in df.columns:
    print(col, " = ",df[col].isnull().sum())
# Out:
# Date  =  0
# Gold_Price  =  0
# Silver  =  1
# Oil_WTI  =  1
# Platinum  =  686
# Copper  =  1
# SP500  =  4
# Nasdaq  =  4
# Dow_Jones  =  4
# MSCI_World  =  2328
# DXY  =  3
# EUR_USD  =  835
# JPY_USD  =  25
# GBP_USD  =  822
# CNY_USD  =  438
# US_10Y_Yield  =  8
# US_2Y_Yield  =  8
# TIP_ETF  =  817
# VIX  =  4
# Gold_ETF_GLD  =  1055
# CPI  =  1
# Fed_Rate  =  1
# Real_Rate_10Y  =  1
# PPI  =  1
# M2_Money  =  1
# Treasury_Spread  =  1
# Unemployment  =  1
# GDP_Growth  =  85
# Industrial_Prod  =  1
# Consumer_Conf  =  1
# MA7  =  499
# EMA7  =  1
# MA14  =  998
# EMA14  =  1
# MA21  =  1431
# EMA21  =  1
# MA50  =  2197
# EMA50  =  1
# MA200  =  2328
# EMA200  =  1
# Return_1d  =  2
# Return_3d  =  4
# Return_7d  =  7
# Return_14d  =  14
# Return_30d  =  30
# Lag_1d  =  90
# Lag_3d  =  103
# Lag_7d  =  107
# Lag_14d  =  113
# Lag_21d  =  115
# RSI_14  =  1063
# MACD  =  1
# MACD_Signal  =  1
# MACD_Hist  =  1
# BB_Upper  =  1378
# BB_Lower  =  1378
# BB_Width  =  1378
# BB_Pos  =  1378
# Volatility_7d  =  7
# Volatility_30d  =  30
# Momentum_14d  =  113
# Gold_Silver_Ratio  =  2
# Gold_Oil_Ratio  =  2
# DayOfWeek  =  1
# Month  =  1
# Quarter  =  1
# Year  =  1
# Target_NextDay  =  89
# Target_Next7d  =  101
# Target_Direction  =  1

# %%
threshold = 0.3
df = df.loc[:, df.isnull().mean() < threshold]

# %%
df.columns
# Out:
# Index(['Date', 'Gold_Price', 'Silver', 'Oil_WTI', 'Platinum', 'Copper',
#        'SP500', 'Nasdaq', 'Dow_Jones', 'DXY', 'JPY_USD', 'CNY_USD',
#        'US_10Y_Yield', 'US_2Y_Yield', 'VIX', 'CPI', 'Fed_Rate',
#        'Real_Rate_10Y', 'PPI', 'M2_Money', 'Treasury_Spread', 'Unemployment',
#        'GDP_Growth', 'Industrial_Prod', 'Consumer_Conf', 'MA7', 'EMA7',
#        'EMA14', 'EMA21', 'EMA50', 'EMA200', 'Return_1d', 'Return_3d',
#        'Return_7d', 'Return_14d', 'Return_30d', 'Lag_1d', 'Lag_3d', 'Lag_7d',
#        'Lag_14d', 'Lag_21d', 'MACD', 'MACD_Signal', 'MACD_Hist',
#        'Volatility_7d', 'Volatility_30d', 'Momentum_14d', 'Gold_Silver_Ratio',
#        'Gold_Oil_Ratio', 'DayOfWeek', 'Month', 'Quarter', 'Year',
#        'Target_NextDay', 'Target_Next7d', 'Target_Direction'],
#       dtype='object')

# %%
df.shape
# Out:
# (2328, 56)

# %%
target_cols = ['Target_NextDay', 'Target_Next7d', 'Target_Direction']

# %%
time_col = ['Date']

# %%
price_cols = [
    'Gold_Price', 'Silver', 'Oil_WTI', 'Platinum', 'Copper',
    'SP500', 'Nasdaq', 'Dow_Jones',
    'DXY', 'EUR_USD', 'JPY_USD', 'GBP_USD', 'CNY_USD',
    'US_10Y_Yield', 'US_2Y_Yield',
    'TIP_ETF', 'VIX', 'Gold_ETF_GLD'
]

# %%
macro_cols = [
    'CPI', 'Fed_Rate', 'Real_Rate_10Y', 'PPI',
    'M2_Money', 'Treasury_Spread',
    'Unemployment', 'GDP_Growth',
    'Industrial_Prod', 'Consumer_Conf'
]

# %%
tech_cols = [
    'MA7', 'EMA7', 'EMA14', 'EMA21', 'EMA50', 'EMA200',
    'MACD', 'MACD_Signal', 'MACD_Hist',
    'Volatility_7d', 'Volatility_30d',
    'Momentum_14d'
]

# %%
return_cols = [
    'Return_1d', 'Return_3d', 'Return_7d',
    'Return_14d', 'Return_30d'
]

# %%
lag_cols = [
    'Lag_1d', 'Lag_3d', 'Lag_7d',
    'Lag_14d', 'Lag_21d'
]

# %%
ratio_cols = [
    'Gold_Silver_Ratio',
    'Gold_Oil_Ratio'
]

# %%
date_features = ['DayOfWeek', 'Month', 'Quarter', 'Year']

# %%
for col in price_cols:
    if col in df.columns:
        df[col] = df[col].ffill()

# %%
df[ratio_cols] = df[ratio_cols].fillna(method='ffill')
# Out:
# /tmp/ipykernel_2899/3335058602.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[ratio_cols] = df[ratio_cols].fillna(method='ffill')

# %%
for col in macro_cols:
  df[col]=df[col].ffill()

# %%
df = df.dropna(subset=tech_cols)

# %%
df = df.dropna(subset=return_cols)

# %%
df[date_features] = df[date_features].fillna(method='ffill')
# Out:
# /tmp/ipykernel_2899/4030072480.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[date_features] = df[date_features].fillna(method='ffill')

# %%
df.isnull().sum()
# Out:
# Date                   0
# Gold_Price             0
# Silver                 0
# Oil_WTI                0
# Platinum               0
# Copper                 0
# SP500                  0
# Nasdaq                 0
# Dow_Jones              0
# DXY                    0
# JPY_USD                0
# CNY_USD              117
# US_10Y_Yield           0
# US_2Y_Yield            0
# VIX                    0
# CPI                    0
# Fed_Rate               0
# Real_Rate_10Y          0
# PPI                    0
# M2_Money               0
# Treasury_Spread        0
# Unemployment           0
# GDP_Growth            38
# Industrial_Prod        0
# Consumer_Conf          0
# MA7                    0
# EMA7                   0
# EMA14                  0
# EMA21                  0
# EMA50                  0
# EMA200                 0
# Return_1d              0
# Return_3d              0
# Return_7d              0
# Return_14d             0
# Return_30d             0
# Lag_1d                 0
# Lag_3d                 0
# Lag_7d                72
# Lag_14d                0
# Lag_21d               61
# MACD                   0
# MACD_Signal            0
# MACD_Hist              0
# Volatility_7d          0
# Volatility_30d         0
# Momentum_14d           0
# Gold_Silver_Ratio      0
# Gold_Oil_Ratio         0
# DayOfWeek              0
# Month                  0
# Quarter                0
# Year                   0
# Target_NextDay         0
# Target_Next7d          0
# Target_Direction       0
# dtype: int64

# %%
df = df.dropna(subset=['Lag_7d', 'Lag_21d'])

# %%
df = df.dropna(subset=['GDP_Growth'])

# %%
df['CNY_USD'] = df['CNY_USD'].fillna(method='ffill').fillna(method='bfill')
# Out:
# /tmp/ipykernel_2899/1921691798.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['CNY_USD'] = df['CNY_USD'].fillna(method='ffill').fillna(method='bfill')

# %%
df.isnull().sum()
# Out:
# Date                 0
# Gold_Price           0
# Silver               0
# Oil_WTI              0
# Platinum             0
# Copper               0
# SP500                0
# Nasdaq               0
# Dow_Jones            0
# DXY                  0
# JPY_USD              0
# CNY_USD              0
# US_10Y_Yield         0
# US_2Y_Yield          0
# VIX                  0
# CPI                  0
# Fed_Rate             0
# Real_Rate_10Y        0
# PPI                  0
# M2_Money             0
# Treasury_Spread      0
# Unemployment         0
# GDP_Growth           0
# Industrial_Prod      0
# Consumer_Conf        0
# MA7                  0
# EMA7                 0
# EMA14                0
# EMA21                0
# EMA50                0
# EMA200               0
# Return_1d            0
# Return_3d            0
# Return_7d            0
# Return_14d           0
# Return_30d           0
# Lag_1d               0
# Lag_3d               0
# Lag_7d               0
# Lag_14d              0
# Lag_21d              0
# MACD                 0
# MACD_Signal          0
# MACD_Hist            0
# Volatility_7d        0
# Volatility_30d       0
# Momentum_14d         0
# Gold_Silver_Ratio    0
# Gold_Oil_Ratio       0
# DayOfWeek            0
# Month                0
# Quarter              0
# Year                 0
# Target_NextDay       0
# Target_Next7d        0
# Target_Direction     0
# dtype: int64

# %% [markdown]
# # Feature Engineering

# %%
df['Gold_DXY_interaction'] = df['Gold_Price'] * df['DXY']
df['Gold_VIX_interaction'] = df['Gold_Price'] * df['VIX']

# %%
df['Rolling_mean_7'] = df['Gold_Price'].rolling(7).mean()
df['Rolling_std_7'] = df['Gold_Price'].rolling(7).std()

# %%
df['Price_diff'] = df['Gold_Price'].diff()
df['Price_pct_change'] = df['Gold_Price'].pct_change()

# %%
df['Gold_SP500_Ratio'] = df['Gold_Price'] / df['SP500']

# %%
import numpy as np

df['Month_sin'] = np.sin(2 * np.pi * df['Month'] / 12)
df['Month_cos'] = np.cos(2 * np.pi * df['Month'] / 12)

# %%
df = df.dropna()

# %% [markdown]
# #Feature selection

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

df.loc[:, 'Date'] = pd.to_datetime(df['Date'], errors='coerce')
corr = df.corr()

plt.figure(figsize=(12,8))
sns.heatmap(corr, cmap='coolwarm')
plt.show()

# %%
corr_target = df.corr()['Target_NextDay'].sort_values(ascending=False)
print(corr_target.head(60))
# Out:
# Target_NextDay          1.000000
# Gold_Price              0.999378
# Lag_1d                  0.998631
# EMA7                    0.998542
# MA7                     0.998125
# Rolling_mean_7          0.997700
# EMA14                   0.997575
# Lag_3d                  0.997453
# EMA21                   0.996741
# Target_Next7d           0.996386
# Lag_7d                  0.994903
# EMA50                   0.993924
# Lag_14d                 0.991199
# Lag_21d                 0.987239
# Gold_DXY_interaction    0.985841
# EMA200                  0.985616
# M2_Money                0.966891
# Date                    0.956910
# Year                    0.956093
# CPI                     0.955456
# Silver                  0.948305
# Gold_SP500_Ratio        0.896029
# PPI                     0.893714
# Platinum                0.814084
# Oil_WTI                 0.789952
# Copper                  0.783921
# Gold_VIX_interaction    0.726904
# Rolling_std_7           0.608708
# Unemployment            0.519030
# Volatility_30d          0.437558
# Nasdaq                  0.398394
# Volatility_7d           0.381199
# MACD_Signal             0.265931
# Dow_Jones               0.263338
# MACD                    0.231537
# Industrial_Prod         0.210622
# VIX                     0.205363
# Gold_Oil_Ratio          0.198273
# SP500                   0.184731
# Return_30d              0.144744
# Momentum_14d            0.099782
# Return_14d              0.066152
# Month                   0.065878
# Quarter                 0.063563
# Price_diff              0.052679
# Month_cos               0.048610
# Price_pct_change        0.033957
# Return_1d               0.032339
# Target_Direction        0.024164
# Return_3d               0.022368
# Return_7d               0.020783
# Treasury_Spread         0.017781
# DayOfWeek               0.005910
# Month_sin              -0.040740
# MACD_Hist              -0.043095
# Fed_Rate               -0.127272
# US_2Y_Yield            -0.184392
# GDP_Growth             -0.275349
# Gold_Silver_Ratio      -0.278048
# Real_Rate_10Y          -0.502252
# Name: Target_NextDay, dtype: float64

# %%
threshold = 0.05
corr_matrix = df.corr()
target_corr = corr_matrix['Target_NextDay'].abs()
weak_features = target_corr[target_corr < threshold].index.tolist()

# %%
df_filtered = df.drop(columns=weak_features)
print(f"deleted{len(weak_features)} week feature: {weak_features}")
# Out:
# deleted10 week feature: ['Treasury_Spread', 'Return_1d', 'Return_3d', 'Return_7d', 'MACD_Hist', 'DayOfWeek', 'Target_Direction', 'Price_pct_change', 'Month_sin', 'Month_cos']

# %%
corr_features = df_filtered.drop(columns=['Target_NextDay']).corr().abs()
upper = corr_features.where(np.triu(np.ones(corr_features.shape), k=1).astype(bool))
to_drop = [column for column in upper.columns if any(upper[column] > 0.95)]

# %%
df_final = df_filtered.drop(columns=to_drop)
print(f"deleted {len(to_drop)} some correlated feature with high relation {to_drop}")
# Out:
# deleted 22 some correlated feature with high relation ['Gold_Price', 'Dow_Jones', 'CPI', 'Fed_Rate', 'PPI', 'M2_Money', 'MA7', 'EMA7', 'EMA14', 'EMA21', 'EMA50', 'EMA200', 'Lag_1d', 'Lag_3d', 'Lag_7d', 'Lag_14d', 'Lag_21d', 'Quarter', 'Year', 'Target_Next7d', 'Gold_DXY_interaction', 'Rolling_mean_7']

# %%
df_final.columns
# Out:
# Index(['Date', 'Silver', 'Oil_WTI', 'Platinum', 'Copper', 'SP500', 'Nasdaq',
#        'DXY', 'JPY_USD', 'CNY_USD', 'US_10Y_Yield', 'US_2Y_Yield', 'VIX',
#        'Real_Rate_10Y', 'Unemployment', 'GDP_Growth', 'Industrial_Prod',
#        'Consumer_Conf', 'Return_14d', 'Return_30d', 'MACD', 'MACD_Signal',
#        'Volatility_7d', 'Volatility_30d', 'Momentum_14d', 'Gold_Silver_Ratio',
#        'Gold_Oil_Ratio', 'Month', 'Target_NextDay', 'Gold_VIX_interaction',
#        'Rolling_std_7', 'Price_diff', 'Gold_SP500_Ratio'],
#       dtype='object')

# %%
X = df_final.drop(columns=['Target_NextDay']).select_dtypes(include=[np.number]).dropna()
y = df_final.loc[X.index, 'Target_NextDay']

# %%
import numpy as np
from sklearn.ensemble import RandomForestRegressor

# %%
model = RandomForestRegressor(n_estimators=100, random_state=42)
model.fit(X, y)
# Out:
# RandomForestRegressor(random_state=42)

# %%
importances = pd.Series(model.feature_importances_, index=X.columns).sort_values(ascending=False)
print("the top 10 feature based on random forest")
print(importances.head(10))
# Out:
# the top 10 feature based on random forest
# CNY_USD             0.807573
# Real_Rate_10Y       0.110345
# Industrial_Prod     0.037697
# Unemployment        0.013690
# Gold_SP500_Ratio    0.005227
# Copper              0.003666
# DXY                 0.003018
# US_10Y_Yield        0.002835
# Month               0.002458
# MACD                0.002215
# dtype: float64
