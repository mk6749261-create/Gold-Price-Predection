# %%
import pandas as pd

df = pd.read_csv('/content/gold_dataset.csv')
df_before = df.copy()

# %%
df.head()
# Out:
#          Date  Gold_Price  Silver    Oil_WTI    Platinum  Copper        SP500  \
# 0  2000-08-30  273.899994   4.930  33.400002  591.400024  0.8850  1502.589966
# 1  2000-08-31  278.299988   5.003  33.099998  586.700012  0.8850  1517.680054
# 2  2000-09-01  277.000000   5.004  33.380001  595.299988  0.8890  1520.770020
# 3  2000-09-05  275.799988   4.998  33.799999  601.299988  0.9060  1507.079956
# 4  2000-09-06  274.200012   4.983  34.950001  611.099976  0.9015  1492.250000
#
#         Nasdaq     Dow_Jones  MSCI_World  ...  Momentum_14d  \
# 0  4103.810059  11103.009766         NaN  ...           NaN
# 1  4206.350098  11215.099609         NaN  ...           NaN
# 2  4234.330078  11238.780273         NaN  ...           NaN
# 3  4143.180176  11260.610352         NaN  ...           NaN
# 4  4013.340088  11310.639648         NaN  ...           NaN
#
#    Gold_Silver_Ratio  Gold_Oil_Ratio  DayOfWeek  Month  Quarter  Year  \
# 0          55.557810        8.200598          2      8        3  2000
# 1          55.626624        8.407855          3      8        3  2000
# 2          55.355713        8.298382          4      9        3  2000
# 3          55.182069        8.159763          1      9        3  2000
# 4          55.027097        7.845494          2      9        3  2000
#
#    Target_NextDay  Target_Next7d  Target_Direction
# 0      278.299988     273.299988                 1
# 1      277.000000     273.100006                 0
# 2             NaN     272.899994                 0
# 3      274.200012     272.399994                 0
# 4      274.000000     272.299988                 0
#
# [5 rows x 70 columns]

# %%
df.shape
# Out:
# (6419, 70)

# %%
df.columns
# Out:
# Index(['Date', 'Gold_Price', 'Silver', 'Oil_WTI', 'Platinum', 'Copper',
#        'SP500', 'Nasdaq', 'Dow_Jones', 'MSCI_World', 'DXY', 'EUR_USD',
#        'JPY_USD', 'GBP_USD', 'CNY_USD', 'US_10Y_Yield', 'US_2Y_Yield',
#        'TIP_ETF', 'VIX', 'Gold_ETF_GLD', 'CPI', 'Fed_Rate', 'Real_Rate_10Y',
#        'PPI', 'M2_Money', 'Treasury_Spread', 'Unemployment', 'GDP_Growth',
#        'Industrial_Prod', 'Consumer_Conf', 'MA7', 'EMA7', 'MA14', 'EMA14',
#        'MA21', 'EMA21', 'MA50', 'EMA50', 'MA200', 'EMA200', 'Return_1d',
#        'Return_3d', 'Return_7d', 'Return_14d', 'Return_30d', 'Lag_1d',
#        'Lag_3d', 'Lag_7d', 'Lag_14d', 'Lag_21d', 'RSI_14', 'MACD',
#        'MACD_Signal', 'MACD_Hist', 'BB_Upper', 'BB_Lower', 'BB_Width',
#        'BB_Pos', 'Volatility_7d', 'Volatility_30d', 'Momentum_14d',
#        'Gold_Silver_Ratio', 'Gold_Oil_Ratio', 'DayOfWeek', 'Month', 'Quarter',
#        'Year', 'Target_NextDay', 'Target_Next7d', 'Target_Direction'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6419 entries, 0 to 6418
# Data columns (total 70 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               6419 non-null   object
#  1   Gold_Price         6419 non-null   float64
#  2   Silver             6418 non-null   float64
#  3   Oil_WTI            6418 non-null   float64
#  4   Platinum           5732 non-null   float64
#  5   Copper             6418 non-null   float64
#  6   SP500              6414 non-null   float64
#  7   Nasdaq             6414 non-null   float64
#  8   Dow_Jones          6414 non-null   float64
#  9   MSCI_World         3571 non-null   float64
#  10  DXY                6416 non-null   float64
#  11  EUR_USD            5579 non-null   float64
#  12  JPY_USD            6389 non-null   float64
#  13  GBP_USD            5592 non-null   float64
#  14  CNY_USD            5975 non-null   float64
#  15  US_10Y_Yield       6409 non-null   float64
#  16  US_2Y_Yield        6409 non-null   float64
#  17  TIP_ETF            5601 non-null   float64
#  18  VIX                6414 non-null   float64
#  19  Gold_ETF_GLD       5363 non-null   float64
#  20  CPI                6419 non-null   float64
#  21  Fed_Rate           6419 non-null   float64
#  22  Real_Rate_10Y      6419 non-null   float64
#  23  PPI                6419 non-null   float64
#  24  M2_Money           6419 non-null   float64
#  25  Treasury_Spread    6419 non-null   float64
#  26  Unemployment       6419 non-null   float64
#  27  GDP_Growth         6335 non-null   float64
#  28  Industrial_Prod    6419 non-null   float64
#  29  Consumer_Conf      6419 non-null   float64
#  30  MA7                5047 non-null   float64
#  31  EMA7               6419 non-null   float64
#  32  MA14               3646 non-null   float64
#  33  EMA14              6419 non-null   float64
#  34  MA21               2450 non-null   float64
#  35  EMA21              6419 non-null   float64
#  36  MA50               289 non-null    float64
#  37  EMA50              6419 non-null   float64
#  38  MA200              0 non-null      float64
#  39  EMA200             6419 non-null   float64
#  40  Return_1d          6418 non-null   float64
#  41  Return_3d          6416 non-null   float64
#  42  Return_7d          6413 non-null   float64
#  43  Return_14d         6406 non-null   float64
#  44  Return_30d         6390 non-null   float64
#  45  Lag_1d             6180 non-null   float64
#  46  Lag_3d             6166 non-null   float64
#  47  Lag_7d             6162 non-null   float64
#  48  Lag_14d            6159 non-null   float64
#  49  Lag_21d            6158 non-null   float64
#  50  RSI_14             3464 non-null   float64
#  51  MACD               6419 non-null   float64
#  52  MACD_Signal        6419 non-null   float64
#  53  MACD_Hist          6419 non-null   float64
#  54  BB_Upper           2598 non-null   float64
#  55  BB_Lower           2598 non-null   float64
#  56  BB_Width           2598 non-null   float64
#  57  BB_Pos             2598 non-null   float64
#  58  Volatility_7d      6413 non-null   float64
#  59  Volatility_30d     6390 non-null   float64
#  60  Momentum_14d       6159 non-null   float64
#  61  Gold_Silver_Ratio  6418 non-null   float64
#  62  Gold_Oil_Ratio     6418 non-null   float64
#  63  DayOfWeek          6419 non-null   int64
#  64  Month              6419 non-null   int64
#  65  Quarter            6419 non-null   int64
#  66  Year               6419 non-null   int64
#  67  Target_NextDay     6181 non-null   float64
#  68  Target_Next7d      6168 non-null   float64
#  69  Target_Direction   6419 non-null   int64
# dtypes: float64(64), int64(5), object(1)
# memory usage: 3.4+ MB

# %%
for col in df.columns:
    print(col, " = ",df[col].isnull().sum())
# Out:
# Date  =  0
# Gold_Price  =  0
# Silver  =  1
# Oil_WTI  =  1
# Platinum  =  687
# Copper  =  1
# SP500  =  5
# Nasdaq  =  5
# Dow_Jones  =  5
# MSCI_World  =  2848
# DXY  =  3
# EUR_USD  =  840
# JPY_USD  =  30
# GBP_USD  =  827
# CNY_USD  =  444
# US_10Y_Yield  =  10
# US_2Y_Yield  =  10
# TIP_ETF  =  818
# VIX  =  5
# Gold_ETF_GLD  =  1056
# CPI  =  0
# Fed_Rate  =  0
# Real_Rate_10Y  =  0
# PPI  =  0
# M2_Money  =  0
# Treasury_Spread  =  0
# Unemployment  =  0
# GDP_Growth  =  84
# Industrial_Prod  =  0
# Consumer_Conf  =  0
# MA7  =  1372
# EMA7  =  0
# MA14  =  2773
# EMA14  =  0
# MA21  =  3969
# EMA21  =  0
# MA50  =  6130
# EMA50  =  0
# MA200  =  6419
# EMA200  =  0
# Return_1d  =  1
# Return_3d  =  3
# Return_7d  =  6
# Return_14d  =  13
# Return_30d  =  29
# Lag_1d  =  239
# Lag_3d  =  253
# Lag_7d  =  257
# Lag_14d  =  260
# Lag_21d  =  261
# RSI_14  =  2955
# MACD  =  0
# MACD_Signal  =  0
# MACD_Hist  =  0
# BB_Upper  =  3821
# BB_Lower  =  3821
# BB_Width  =  3821
# BB_Pos  =  3821
# Volatility_7d  =  6
# Volatility_30d  =  29
# Momentum_14d  =  260
# Gold_Silver_Ratio  =  1
# Gold_Oil_Ratio  =  1
# DayOfWeek  =  0
# Month  =  0
# Quarter  =  0
# Year  =  0
# Target_NextDay  =  238
# Target_Next7d  =  251
# Target_Direction  =  0

# %%
df.isnull().sum()
# Out:
# Date                  0
# Gold_Price            0
# Silver                1
# Oil_WTI               1
# Platinum            687
#                    ...
# Quarter               0
# Year                  0
# Target_NextDay      238
# Target_Next7d       251
# Target_Direction      0
# Length: 70, dtype: int64

# %%
df.describe()
# Out:
#         Gold_Price       Silver      Oil_WTI     Platinum       Copper  \
# count  6419.000000  6418.000000  6418.000000  5732.000000  6418.000000
# mean   1285.970462    18.584920    64.770570  1093.479588     2.871972
# std     806.472608    11.566541    24.525810   367.649752     1.201432
# min     255.100006     4.026000   -37.630001   412.500000     0.604000
# 25%     652.800018    12.252250    46.517499   870.500000     2.147000
# 50%    1252.099976    17.038500    63.809999   979.500000     3.052250
# 75%    1700.350037    23.754000    81.995001  1376.799988     3.709500
# max    5318.399902   115.080002   145.289993  2852.399902     6.175500
#
#              SP500        Nasdaq     Dow_Jones   MSCI_World          DXY  ...  \
# count  6414.000000   6414.000000   6414.000000  3571.000000  6416.000000  ...
# mean   2336.385885   6252.892145  19485.196210    89.983967    92.528533  ...
# std    1525.610178   5555.604981  10867.973573    38.426349    11.131566  ...
# min     676.530029   1114.109985   6547.049805    37.733318    71.330002  ...
# 25%    1207.029999   2207.840027  10679.027100    58.769709    82.550003  ...
# 50%    1643.095032   3600.234985  15077.024902    78.583092    93.080002  ...
# 75%    2972.850037   8195.647461  26475.987305   116.109600    99.522497  ...
# max    6978.600098  23958.470703  50188.140625   192.369995   120.900002  ...
#
#        Momentum_14d  Gold_Silver_Ratio  Gold_Oil_Ratio    DayOfWeek  \
# count   6159.000000        6418.000000     6418.000000  6419.000000
# mean       9.342799          69.170258       20.522467     2.020876
# std       67.713223          13.268056       13.406191     1.398548
# min     -770.600098          31.995078      -45.219238     0.000000
# 25%      -16.199951          59.423771       11.490888     1.000000
# 50%        5.100006          68.632369       17.021091     2.000000
# 75%       31.400024          78.757052       25.267730     3.000000
# max      851.899902         125.888376      167.652339     4.000000
#
#              Month      Quarter         Year  Target_NextDay  Target_Next7d  \
# count  6419.000000  6419.000000  6419.000000     6181.000000    6168.000000
# mean      6.546814     2.514566  2012.973672     1288.646027    1293.606063
# std       3.447118     1.121157     7.385234      809.681440     814.117404
# min       1.000000     1.000000  2000.000000      255.100006     255.100006
# 25%       4.000000     2.000000  2007.000000      653.400024     656.700012
# 50%       7.000000     3.000000  2013.000000     1252.699951    1253.800049
# 75%      10.000000     4.000000  2019.000000     1702.400024    1704.575012
# max      12.000000     4.000000  2026.000000     5318.399902    5318.399902
#
#        Target_Direction
# count       6419.000000
# mean           0.505686
# std            0.500007
# min            0.000000
# 25%            0.000000
# 50%            1.000000
# 75%            1.000000
# max            1.000000
#
# [8 rows x 69 columns]

# %%
for col in df.columns:
    print(col, " = ",df[col].isnull().sum())
# Out:
# Date  =  0
# Gold_Price  =  0
# Silver  =  1
# Oil_WTI  =  1
# Platinum  =  687
# Copper  =  1
# SP500  =  5
# Nasdaq  =  5
# Dow_Jones  =  5
# MSCI_World  =  2848
# DXY  =  3
# EUR_USD  =  840
# JPY_USD  =  30
# GBP_USD  =  827
# CNY_USD  =  444
# US_10Y_Yield  =  10
# US_2Y_Yield  =  10
# TIP_ETF  =  818
# VIX  =  5
# Gold_ETF_GLD  =  1056
# CPI  =  0
# Fed_Rate  =  0
# Real_Rate_10Y  =  0
# PPI  =  0
# M2_Money  =  0
# Treasury_Spread  =  0
# Unemployment  =  0
# GDP_Growth  =  84
# Industrial_Prod  =  0
# Consumer_Conf  =  0
# MA7  =  1372
# EMA7  =  0
# MA14  =  2773
# EMA14  =  0
# MA21  =  3969
# EMA21  =  0
# MA50  =  6130
# EMA50  =  0
# MA200  =  6419
# EMA200  =  0
# Return_1d  =  1
# Return_3d  =  3
# Return_7d  =  6
# Return_14d  =  13
# Return_30d  =  29
# Lag_1d  =  239
# Lag_3d  =  253
# Lag_7d  =  257
# Lag_14d  =  260
# Lag_21d  =  261
# RSI_14  =  2955
# MACD  =  0
# MACD_Signal  =  0
# MACD_Hist  =  0
# BB_Upper  =  3821
# BB_Lower  =  3821
# BB_Width  =  3821
# BB_Pos  =  3821
# Volatility_7d  =  6
# Volatility_30d  =  29
# Momentum_14d  =  260
# Gold_Silver_Ratio  =  1
# Gold_Oil_Ratio  =  1
# DayOfWeek  =  0
# Month  =  0
# Quarter  =  0
# Year  =  0
# Target_NextDay  =  238
# Target_Next7d  =  251
# Target_Direction  =  0

# %%
threshold = 0.3
df = df.loc[:, df.isnull().mean() < threshold]

# %%
df.columns
# Out:
# Index(['Date', 'Gold_Price', 'Silver', 'Oil_WTI', 'Platinum', 'Copper',
#        'SP500', 'Nasdaq', 'Dow_Jones', 'DXY', 'EUR_USD', 'JPY_USD', 'GBP_USD',
#        'CNY_USD', 'US_10Y_Yield', 'US_2Y_Yield', 'TIP_ETF', 'VIX',
#        'Gold_ETF_GLD', 'CPI', 'Fed_Rate', 'Real_Rate_10Y', 'PPI', 'M2_Money',
#        'Treasury_Spread', 'Unemployment', 'GDP_Growth', 'Industrial_Prod',
#        'Consumer_Conf', 'MA7', 'EMA7', 'EMA14', 'EMA21', 'EMA50', 'EMA200',
#        'Return_1d', 'Return_3d', 'Return_7d', 'Return_14d', 'Return_30d',
#        'Lag_1d', 'Lag_3d', 'Lag_7d', 'Lag_14d', 'Lag_21d', 'MACD',
#        'MACD_Signal', 'MACD_Hist', 'Volatility_7d', 'Volatility_30d',
#        'Momentum_14d', 'Gold_Silver_Ratio', 'Gold_Oil_Ratio', 'DayOfWeek',
#        'Month', 'Quarter', 'Year', 'Target_NextDay', 'Target_Next7d',
#        'Target_Direction'],
#       dtype='object')

# %%
df.shape
# Out:
# (6419, 60)

# %%
target_cols = ['Target_NextDay', 'Target_Next7d', 'Target_Direction']

# %%
time_col = ['Date']

# %%
price_cols = [
    'Gold_Price', 'Silver', 'Oil_WTI', 'Platinum', 'Copper',
    'SP500', 'Nasdaq', 'Dow_Jones',
    'DXY', 'EUR_USD', 'JPY_USD', 'GBP_USD', 'CNY_USD',
    'US_10Y_Yield', 'US_2Y_Yield',
    'TIP_ETF', 'VIX', 'Gold_ETF_GLD'
]

# %%
macro_cols = [
    'CPI', 'Fed_Rate', 'Real_Rate_10Y', 'PPI',
    'M2_Money', 'Treasury_Spread',
    'Unemployment', 'GDP_Growth',
    'Industrial_Prod', 'Consumer_Conf'
]

# %%
tech_cols = [
    'MA7', 'EMA7', 'EMA14', 'EMA21', 'EMA50', 'EMA200',
    'MACD', 'MACD_Signal', 'MACD_Hist',
    'Volatility_7d', 'Volatility_30d',
    'Momentum_14d'
]

# %%
return_cols = [
    'Return_1d', 'Return_3d', 'Return_7d',
    'Return_14d', 'Return_30d'
]

# %%
lag_cols = [
    'Lag_1d', 'Lag_3d', 'Lag_7d',
    'Lag_14d', 'Lag_21d'
]

# %%
ratio_cols = [
    'Gold_Silver_Ratio',
    'Gold_Oil_Ratio'
]

# %%
date_features = ['DayOfWeek', 'Month', 'Quarter', 'Year']

# %%
for col in price_cols:
    if col in df.columns:
        df[col] = df[col].ffill()

# %%
df[ratio_cols] = df[ratio_cols].fillna(method='ffill')
# Out:
# /tmp/ipykernel_15302/3335058602.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[ratio_cols] = df[ratio_cols].fillna(method='ffill')

# %%
for col in macro_cols:
  df[col]=df[col].ffill()

# %%
df = df.dropna(subset=tech_cols)

# %%
df = df.dropna(subset=return_cols)

# %%
df[date_features] = df[date_features].fillna(method='ffill')
# Out:
# /tmp/ipykernel_15302/4030072480.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[date_features] = df[date_features].fillna(method='ffill')

# %%
df.isnull().sum()
# Out:
# Date                   0
# Gold_Price             0
# Silver                 0
# Oil_WTI                0
# Platinum               0
# Copper                 0
# SP500                  0
# Nasdaq                 0
# Dow_Jones              0
# DXY                    0
# EUR_USD              589
# JPY_USD                0
# GBP_USD              589
# CNY_USD              128
# US_10Y_Yield           0
# US_2Y_Yield            0
# TIP_ETF              589
# VIX                    0
# Gold_ETF_GLD         764
# CPI                    0
# Fed_Rate               0
# Real_Rate_10Y          0
# PPI                    0
# M2_Money               0
# Treasury_Spread        0
# Unemployment           0
# GDP_Growth            43
# Industrial_Prod        0
# Consumer_Conf          0
# MA7                    0
# EMA7                   0
# EMA14                  0
# EMA21                  0
# EMA50                  0
# EMA200                 0
# Return_1d              0
# Return_3d              0
# Return_7d              0
# Return_14d             0
# Return_30d             0
# Lag_1d                 0
# Lag_3d                 0
# Lag_7d               211
# Lag_14d                0
# Lag_21d              177
# MACD                   0
# MACD_Signal            0
# MACD_Hist              0
# Volatility_7d          0
# Volatility_30d         0
# Momentum_14d           0
# Gold_Silver_Ratio      0
# Gold_Oil_Ratio         0
# DayOfWeek              0
# Month                  0
# Quarter                0
# Year                   0
# Target_NextDay       200
# Target_Next7d        214
# Target_Direction       0
# dtype: int64

# %%
df = df.dropna(subset=['Lag_7d', 'Lag_21d'])

# %%
df = df.dropna(subset=['GDP_Growth'])

# %%
df['CNY_USD'] = df['CNY_USD'].fillna(method='ffill').fillna(method='bfill')
# Out:
# /tmp/ipykernel_15302/1921691798.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['CNY_USD'] = df['CNY_USD'].fillna(method='ffill').fillna(method='bfill')

# %%
df.isnull().sum()
# Out:
# Date                   0
# Gold_Price             0
# Silver                 0
# Oil_WTI                0
# Platinum               0
# Copper                 0
# SP500                  0
# Nasdaq                 0
# Dow_Jones              0
# DXY                    0
# EUR_USD              501
# JPY_USD                0
# GBP_USD              501
# CNY_USD                0
# US_10Y_Yield           0
# US_2Y_Yield            0
# TIP_ETF              501
# VIX                    0
# Gold_ETF_GLD         660
# CPI                    0
# Fed_Rate               0
# Real_Rate_10Y          0
# PPI                    0
# M2_Money               0
# Treasury_Spread        0
# Unemployment           0
# GDP_Growth             0
# Industrial_Prod        0
# Consumer_Conf          0
# MA7                    0
# EMA7                   0
# EMA14                  0
# EMA21                  0
# EMA50                  0
# EMA200                 0
# Return_1d              0
# Return_3d              0
# Return_7d              0
# Return_14d             0
# Return_30d             0
# Lag_1d                 0
# Lag_3d                 0
# Lag_7d                 0
# Lag_14d                0
# Lag_21d                0
# MACD                   0
# MACD_Signal            0
# MACD_Hist              0
# Volatility_7d          0
# Volatility_30d         0
# Momentum_14d           0
# Gold_Silver_Ratio      0
# Gold_Oil_Ratio         0
# DayOfWeek              0
# Month                  0
# Quarter                0
# Year                   0
# Target_NextDay       188
# Target_Next7d        199
# Target_Direction       0
# dtype: int64

# %% [markdown]
# # Feature Engineering

# %%
df['Gold_DXY_interaction'] = df['Gold_Price'] * df['DXY']
df['Gold_VIX_interaction'] = df['Gold_Price'] * df['VIX']

# %%
df['Rolling_mean_7'] = df['Gold_Price'].rolling(7).mean()
df['Rolling_std_7'] = df['Gold_Price'].rolling(7).std()

# %%
df['Price_diff'] = df['Gold_Price'].diff()
df['Price_pct_change'] = df['Gold_Price'].pct_change()

# %%
df['Gold_SP500_Ratio'] = df['Gold_Price'] / df['SP500']

# %%
import numpy as np

df['Month_sin'] = np.sin(2 * np.pi * df['Month'] / 12)
df['Month_cos'] = np.cos(2 * np.pi * df['Month'] / 12)

# %%
df = df.dropna()

# %% [markdown]
# #Feature selection

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Exclude 'Date' column before calculating correlation
corr = df.drop(columns=['Date']).corr()

plt.figure(figsize=(12,8))
sns.heatmap(corr, cmap='coolwarm')
plt.show()

# %%
corr_target = df.drop(columns=['Date']).corr()['Target_NextDay'].sort_values(ascending=False)
print(corr_target.head(60))
# Out:
# Target_NextDay          1.000000
# Gold_Price              0.999496
# Gold_ETF_GLD            0.999113
# EMA7                    0.999086
# Lag_1d                  0.999003
# MA7                     0.998824
# Rolling_mean_7          0.998712
# EMA14                   0.998601
# Lag_3d                  0.998275
# EMA21                   0.998141
# Target_Next7d           0.997676
# Lag_7d                  0.997068
# EMA50                   0.996452
# Lag_14d                 0.995190
# Lag_21d                 0.993661
# Gold_DXY_interaction    0.986950
# EMA200                  0.985697
# Silver                  0.878540
# Nasdaq                  0.869976
# CPI                     0.859935
# SP500                   0.859309
# Dow_Jones               0.830386
# PPI                     0.805266
# Gold_Oil_Ratio          0.798101
# TIP_ETF                 0.797544
# Year                    0.794340
# M2_Money                0.783968
# Gold_VIX_interaction    0.782508
# Copper                  0.734184
# Rolling_std_7           0.653571
# MACD_Signal             0.572357
# JPY_USD                 0.540600
# MACD                    0.506309
# DXY                     0.477496
# Gold_Silver_Ratio       0.401409
# Momentum_14d            0.231932
# Return_30d              0.211294
# Industrial_Prod         0.210113
# US_2Y_Yield             0.204813
# Fed_Rate                0.182778
# Platinum                0.170377
# Volatility_7d           0.117351
# Return_14d              0.117081
# Volatility_30d          0.110857
# Return_7d               0.073788
# Month_cos               0.065949
# Price_diff              0.060710
# GDP_Growth              0.059122
# Return_3d               0.043139
# VIX                     0.036667
# Month_sin               0.036171
# Target_Direction        0.035936
# Price_pct_change        0.030287
# Oil_WTI                 0.026145
# Return_1d               0.011256
# DayOfWeek              -0.005740
# Gold_SP500_Ratio       -0.006266
# US_10Y_Yield           -0.009543
# Quarter                -0.022349
# Month                  -0.028420
# Name: Target_NextDay, dtype: float64

# %%
threshold = 0.05
corr_matrix = df.drop(columns=['Date']).corr()
target_corr = corr_matrix['Target_NextDay'].abs()
weak_features = target_corr[target_corr < threshold].index.tolist()

# %%
df_filtered = df.drop(columns=weak_features)
print(f"deleted{len(weak_features)} week feature: {weak_features}")
# Out:
# deleted12 week feature: ['Oil_WTI', 'US_10Y_Yield', 'VIX', 'Return_1d', 'Return_3d', 'DayOfWeek', 'Month', 'Quarter', 'Target_Direction', 'Price_pct_change', 'Gold_SP500_Ratio', 'Month_sin']

# %%
corr_features = df_filtered.drop(columns=['Target_NextDay', 'Date']).corr().abs()
upper = corr_features.where(np.triu(np.ones(corr_features.shape), k=1).astype(bool))
to_drop = [column for column in upper.columns if any(upper[column] > 0.95)]

# %%
df_final = df_filtered.drop(columns=to_drop)
print(f"deleted {len(to_drop)} some correlated feature with high relation {to_drop}")
# Out:
# deleted 23 some correlated feature with high relation ['Nasdaq', 'Dow_Jones', 'EUR_USD', 'Gold_ETF_GLD', 'CPI', 'Fed_Rate', 'M2_Money', 'MA7', 'EMA7', 'EMA14', 'EMA21', 'EMA50', 'EMA200', 'Lag_1d', 'Lag_3d', 'Lag_7d', 'Lag_14d', 'Lag_21d', 'MACD_Signal', 'Year', 'Target_Next7d', 'Gold_DXY_interaction', 'Rolling_mean_7']

# %%
df_final.columns
# Out:
# Index(['Date', 'Gold_Price', 'Silver', 'Platinum', 'Copper', 'SP500', 'DXY',
#        'JPY_USD', 'GBP_USD', 'CNY_USD', 'US_2Y_Yield', 'TIP_ETF',
#        'Real_Rate_10Y', 'PPI', 'Treasury_Spread', 'Unemployment', 'GDP_Growth',
#        'Industrial_Prod', 'Consumer_Conf', 'Return_7d', 'Return_14d',
#        'Return_30d', 'MACD', 'MACD_Hist', 'Volatility_7d', 'Volatility_30d',
#        'Momentum_14d', 'Gold_Silver_Ratio', 'Gold_Oil_Ratio', 'Target_NextDay',
#        'Gold_VIX_interaction', 'Rolling_std_7', 'Price_diff', 'Month_cos'],
#       dtype='object')

# %%
X = df_final.drop(columns=['Target_NextDay']).select_dtypes(include=[np.number]).dropna()
y = df_final.loc[X.index, 'Target_NextDay']

# %%
import numpy as np
from sklearn.ensemble import RandomForestRegressor

# %%
model = RandomForestRegressor(n_estimators=100, random_state=42)
model.fit(X, y)
# Out:
# RandomForestRegressor(random_state=42)

# %%
importances = pd.Series(model.feature_importances_, index=X.columns).sort_values(ascending=False)
print("the top 10 feature based on random forest")
print(importances.head(10))
# Out:
# the top 10 feature based on random forest
# Gold_Price        0.928238
# Silver            0.020115
# TIP_ETF           0.014394
# Unemployment      0.013492
# US_2Y_Yield       0.010285
# CNY_USD           0.005598
# Gold_Oil_Ratio    0.002357
# Platinum          0.001983
# SP500             0.000954
# DXY               0.000516
# dtype: float64
